# %% [markdown]
# # Modelos predictivos de regresión lineal uni-variable
#
# Por Rodolfo Antonio Zea Posadas

# %% [markdown]
# Para acceder al enunciado del proyecto, por favor dar clic [aqui](https://github.com/razp26/python-jupyterNotebooks/blob/master/Python%20para%20Data%20Science/Proyecto/Enunciado.pdf)
#
# Como primer paso para la solucion, se importan las librerias que se utilizaran.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn import linear_model
import pandas as pd

import tensorflow as tf

# %% [markdown]
# Una vez hemos importado las librerias que utilizaremos en la solucion, procedemos a cargar los datos de entrada. Estos datos se encuentran el archivo [proyecto_training_data.npy](https://github.com/razp26/python-jupyterNotebooks/blob/master/Python%20para%20Data%20Science/Proyecto/proyecto_training_data.npy) y la descripcion de la informacion del archivo se lista a continuacion:
#
# *Data fields*
# *Here's a brief version of what you'll find in the data description file.*
#
# *SalePrice - the property's sale price in dollars. This is the target variable that you're trying to predict.*
#
#
# *OverallQual: Overall material and finish quality, rates the overall material and finish of the house*
#
#        10	Very Excellent
#        9	Excellent
#        8	Very Good
#        7	Good
#        6	Above Average
#        5	Average
#        4	Below Average
#        3	Fair
#        2	Poor
#        1	Very Poor
#
#
# *1stFlrSF: First Floor square feet*
#
# *TotRmsAbvGrd: Total rooms above grade (does not include bathrooms)*
#
# *YearBuilt: Original construction date*
#
# *LotFrontage: Linear feet of street connected to property*
#
# [Archivo de referencia](https://github.com/razp26/python-jupyterNotebooks/blob/master/Python%20para%20Data%20Science/Proyecto/Data_fields.txt)

# %%
data = np.load('proyecto_training_data.npy')
print(np.shape(data))
# Out:
# (1460, 6)

# %% [markdown]
# De la carga inicial de datos, se utilizará una proporción del 80% para realizar el análisis exploratorio, la selección de variables a utilizar y para crear modelos predictivos. A este subconjunto de datos se le llamara datos de entrenamiento.

# %%
n_train_rows = int(np.shape(data)[0]*0.8)
data_train = data[0:n_train_rows]
print (np.shape(data_train))
# Out:
# (1168, 6)

# %% [markdown]
# El 20% restante se utilizará para probar, validar y evaluar los modelos resultantes. A este subconjunto de datos se le llamara datos de validación y pruebas.

# %%
n_test_rows = int(np.shape(data)[0]*0.2)
data_test = data[-1*n_test_rows:]
print(np.shape(data_test))
# Out:
# (292, 6)

# %% [markdown]
# # Análisis exploratorio de datos
#
# Como primer punto, para comenzar a familiarizarnos con la data que se va a utilizar para proponer los modelos, aplicaraemos algunos conceptos de estadística descriptiva para ver la forma en que se distribuyen los datos.
#
# Para cada variable se calculará lo siguiente:
#
#     1. Media
#     2. Valor máximo
#     3. Valor mínimo
#     4. Rango
#     5. Desviación estándar

# %%
# Calculamos la media por columna
data_mean = np.nanmean(data_train, axis=0)
print('Media')
print('SalePrice: ' + str(data_mean[0]))
print('OverallQual: ' + str(data_mean[1]))
print('1stFlrSF: ' + str(data_mean[2]))
print('TotRmsAbvGrd: ' + str(data_mean[3]))
print('YearBuilt: ' + str(data_mean[4]))
print('LotFrontage: ' + str(data_mean[5]))

# Calculamos el valor máximo por columna
data_max = np.nanmax(data_train, axis=0)
print('\nValor máximo')
print('SalePrice: ' + str(data_max[0]))
print('OverallQual: ' + str(data_max[1]))
print('1stFlrSF: ' + str(data_max[2]))
print('TotRmsAbvGrd: ' + str(data_max[3]))
print('YearBuilt: ' + str(data_max[4]))
print('LotFrontage: ' + str(data_max[5]))

# Calculamos el valor mínimo por columna
data_min = np.nanmin(data_train, axis=0)
print('\nValor mínimo')
print('SalePrice: ' + str(data_min[0]))
print('OverallQual: ' + str(data_min[1]))
print('1stFlrSF: ' + str(data_min[2]))
print('TotRmsAbvGrd: ' + str(data_min[3]))
print('YearBuilt: ' + str(data_min[4]))
print('LotFrontage: ' + str(data_min[5]))

# Calculamos el rango por columna
data_rango = data_max - data_min
print('\nRango')
print('SalePrice: ' + str(data_rango[0]))
print('OverallQual: ' + str(data_rango[1]))
print('1stFlrSF: ' + str(data_rango[2]))
print('TotRmsAbvGrd: ' + str(data_rango[3]))
print('YearBuilt: ' + str(data_rango[4]))
print('LotFrontage: ' + str(data_rango[5]))

# Calculamos la desviación estándar por columna
data_std = np.nanstd(data_train, axis=0)
print('\nDesviación estándar')
print('SalePrice: ' + str(data_std[0]))
print('OverallQual: ' + str(data_std[1]))
print('1stFlrSF: ' + str(data_std[2]))
print('TotRmsAbvGrd: ' + str(data_std[3]))
print('YearBuilt: ' + str(data_std[4]))
print('LotFrontage: ' + str(data_std[5]))
# Out:
# Media
# SalePrice: 180590.27739726027
# OverallQual: 6.101027397260274
# 1stFlrSF: 1156.3236301369864
# TotRmsAbvGrd: 6.4854452054794525
# YearBuilt: 1971.451198630137
# LotFrontage: 69.94698544698545
#
# Valor máximo
# SalePrice: 755000.0
# OverallQual: 10.0
# 1stFlrSF: 3228.0
# TotRmsAbvGrd: 14.0
# YearBuilt: 2010.0
# LotFrontage: 313.0
#
# Valor mínimo
# SalePrice: 34900.0
# OverallQual: 1.0
# 1stFlrSF: 334.0
# TotRmsAbvGrd: 2.0
# YearBuilt: 1875.0
# LotFrontage: 21.0
#
# Rango
# SalePrice: 720100.0
# OverallQual: 9.0
# 1stFlrSF: 2894.0
# TotRmsAbvGrd: 12.0
# YearBuilt: 135.0
# LotFrontage: 292.0
#
# Desviación estándar
# SalePrice: 78781.95108033362
# OverallQual: 1.377435193240741
# 1stFlrSF: 373.620331503586
# TotRmsAbvGrd: 1.6084517167387253
# YearBuilt: 29.93888206867768
# LotFrontage: 23.4659548199304

# %% [markdown]
# Continuando con el análisis exploratorio de los datos, se procede a graficar un histograma para cada una de las variables.

# %%
label_sale_price = pd.Series(data_train[:,0], name="SalePrice")
hist_sale_price = sns.distplot(label_sale_price.dropna(), color="orange")
hist_sale_price.set_title('Variable SalePrice')
# Out:
# Text(0.5, 1.0, 'Variable SalePrice')

# %%
label_overall_quality = pd.Series(data_train[:,1], name="OverallQual")
hist_overall_quality = sns.distplot(label_overall_quality.dropna(), color="red")
hist_overall_quality.set_title('Variable OverallQual')
# Out:
# Text(0.5, 1.0, 'Variable OverallQual')

# %%
label_first_floor_sf = pd.Series(data_train[:,2], name="1stFlrSF")
hist_first_floor_sf = sns.distplot(label_first_floor_sf.dropna(), color="purple")
hist_first_floor_sf.set_title("Variable 1stFlrSF")
# Out:
# Text(0.5, 1.0, 'Variable 1stFlrSF')

# %%
label_total_rooms_above_grade = pd.Series(data_train[:,3], name="TotRmsAbvGrd")
hist_total_rooms_above_grade = sns.distplot(label_total_rooms_above_grade.dropna())
hist_total_rooms_above_grade.set_title('Variable TotRmsAbvGrd')
# Out:
# Text(0.5, 1.0, 'Variable TotRmsAbvGrd')

# %%
label_year_built = pd.Series(data_train[:,4], name="YearBuilt")
hist_year_built = sns.distplot(label_year_built.dropna(), color="blue")
hist_year_built.set_title('Variable YearBuilt')
# Out:
# Text(0.5, 1.0, 'Variable YearBuilt')

# %%
label_lot_frontage = pd.Series(data_train[:,5], name="LotFrontage")
hist_lot_frontage = sns.distplot(label_lot_frontage.dropna(), color="green")
hist_lot_frontage.set_title('Variable LotFrontage')
# Out:
# Text(0.5, 1.0, 'Variable LotFrontage')

# %% [markdown]
# A continuación procedemos a calcular el coeficiente de correlación entre la variable dependiente (SalePrice) y cada variable independiente (OverallQual, 1stFlrSF, TotRmsAbvGrd, YearBuilt y LotFrontage)

# %%
coef_overall_quality = np.corrcoef(data_train[:,1], data_train[:,0])[0,1]
print('El coeficiente de correlación entre SalePrice y OverallQual es: ' + str(coef_overall_quality))

plt.scatter(data_train[:,1], data_train[:,0], color="red")
plt.title("SalePrice vs OverallQual - Coeficiente de correlación: " + str(coef_overall_quality))
plt.xlabel("OverallQual")
plt.ylabel("SalePrice")
plt.show()
# Out:
# El coeficiente de correlación entre SalePrice y OverallQual es: 0.7939900504626408

# %%
coef_first_floor_sf = np.corrcoef(data_train[:,2], data_train[:,0])[0,1]
print('El coeficiente de correlación entre SalePrice y 1stFlrSF es: ' + str(coef_first_floor_sf))

plt.scatter(data_train[:,2], data_train[:,0], color="purple")
plt.title("SalePrice vs 1stFlrSF - Coeficiente de correlación: " + str(coef_first_floor_sf))
plt.xlabel("1stFlrSF")
plt.ylabel("SalePrice")
plt.show()
# Out:
# El coeficiente de correlación entre SalePrice y 1stFlrSF es: 0.6162887000998717

# %%
coef_tot_rooms_above_ground = np.corrcoef(data_train[:,3], data_train[:,0])[0,1]
print('El coeficiente de correlación entre SalePrice y TotRmsAbvGrd es: ' + str(coef_tot_rooms_above_ground))

plt.scatter(data_train[:,3], data_train[:,0])
plt.title("SalePrice vs TotRmsAbvGrd - Coeficiente de correlación: " + str(coef_tot_rooms_above_ground))
plt.xlabel("TotRmsAbvGrd")
plt.ylabel("SalePrice")
plt.show()
# Out:
# El coeficiente de correlación entre SalePrice y TotRmsAbvGrd es: 0.5647069399593067

# %%
coef_year_built = np.corrcoef(data_train[:,4], data_train[:,0])[0,1]
print('El coeficiente de correlación entre SalePrice y YearBuilt es: ' + str(coef_year_built))

plt.scatter(data_train[:,4], data_train[:,0], color="blue")
plt.title("SalePrice vs YearBuilt - Coeficiente de correlación: " + str(coef_year_built))
plt.xlabel("YearBuilt")
plt.ylabel("SalePrice")
plt.show()
# Out:
# El coeficiente de correlación entre SalePrice y YearBuilt es: 0.5341706927117515

# %%
data_without_nan = data_train[~np.isnan(data_train).any(axis=1)]
coef_lot_frontage = np.corrcoef(data_without_nan[:,5], data_without_nan[:,0])[0,1]
print('El coeficiente de correlación entre SalePrice y LotFrontage es: ' + str(coef_lot_frontage))

plt.scatter(data_without_nan[:,5], data_without_nan[:,0], color="green")
plt.title("SalePrice vs LotFrontage - Coeficiente de correlación: " + str(coef_lot_frontage))
plt.xlabel("LotFrontage")
plt.ylabel("SalePrice")
plt.show()
# Out:
# El coeficiente de correlación entre SalePrice y LotFrontage es: 0.3632916166538921

# %% [markdown]
# En base a los resultados del análisis exploratorio de los datos, se eligen las variables OverallQual y 1stFlrSF debido a que son las que presentan una mayor correlación con la variable dependiente SalePrice.
#
# # Función para entrenar un modelo de regresión lineal de una variable
#
# A continuación definimos una función cuya finalidad es entrenar un modelo de regresión lineal de una variable. Dicho modelo tiene la forma:
#
# y = mx + b
#
# La función recibe los siguientes parámetros:
#
#     1- vector con  la variable independiente “x” ,
#     2- vector con la variable dependiente “y”,
#     3- un entero “epochs” que indica por cuantas iteraciones entrenar el modelo.
#     4- un entero  “imprimir_error_cada”  , que nos indica cada cuantas iteraciones queremos imprimir a través de print : el número de iteración, el error del modelo en esa iteración, si imprimir_error_cada = 10, se despliega en pantalla el error en las iteraciones: 10,20,30,40,50
#     5- escalar lr(learning rate): es usado como parte de la expresión matemática para actualizar en cada iteración los parámetros del modelo.

# %%
def modelo_lineal(x, y, epochs, imprimir_error_cada, lr):
    # Se crea una matriz inicial con dos columnas. La primera es x y la segunda se inicaliza con 1
    matriz_entrenamiento = np.column_stack((x, np.ones(x.shape[0], dtype=int)))
    
    # Se inicializa un vector de (m,b) con valores de 0
    # m = vector_mb[0]
    # b = vector_mb[1]
    vector_mb = np.zeros((2))
    
    # Vector donde se almacenan los errores
    errores = np.zeros(shape=(epochs,2))
    
    # Inicializamos nuestro diccionario con los valores del modelo por iteración
    diccionario_resultados = {}
    
    for i in range(0, epochs+1):
        # Se calcula el valor de yhat
        yhat = np.matmul(matriz_entrenamiento, vector_mb)
        # Se calcula el valor del error en la iteración
        error = (1/2)*np.mean(np.power(y - yhat, 2))
        
        #Descartamos cuando i=0 ya que los valores de m y b son con los que se inicializó la función
        if i > 0:
            # Almacenamos el modelo resultante de cada iteración
            diccionario_resultados[i] = vector_mb.copy()
            # Se almacena el error de la iteración en el vector de errores
            errores[i-1,0] = i
            errores[i-1,1] = error
        
        # Se calculan los gradientes
        gradiente_mb = np.mean((yhat - y).reshape(y.size,1) * matriz_entrenamiento, axis=0)
        # Se actualizan los valores de m y b
        vector_mb -= lr * gradiente_mb
        # Verificamos si se debe de imprimir el error de la iteracion
        if (i > 0) and (i % imprimir_error_cada == 0):
            print('Iteración: ' + str(i))
            print('Error del modelo: ' + str(error))
    
    # Retornamos el arreglo de vectores y el diccionario de resultados
    return errores, diccionario_resultados

# %% [markdown]
# # Función para entrenar un modelo de regresión lineal de una variable utilizando Tensorflow
#
# Ahora utilizamos Tensorflow para colcular los coeficientes de regresión (parámetros) que se utilizan para construir el modelo de regresión lineal.
#
# El modelo a construir tendrá la forma:
#
# y = mx + b
#
# Donde los parámetros a estimar son m (weights) y b (biases).

# %%
def modelo_lineal_tf(x, y, epochs, imprimir_error_cada, lr):
    
    X = tf.placeholder("float") 
    Y = tf.placeholder("float") 
    
    # Declaramos dos variables, una para los "weights" y la otra para "biases" y los inicializaremos con valores aleatorios.
    m = tf.Variable(np.random.randn(), name="m")
    b = tf.Variable(np.random.randn(), name="b")
    
    # Construimos la hipótesis o modelo de regresion lineal 
    #yhat = tf.add(tf.multiply(x, m), b)
    yhat = tf.add(x * m, b)
    
    # Definimos la función de costo (error)
    costo = tf.reduce_sum(tf.pow(yhat-y, 2)) / (2 * len(x))
    
    # Aplicamos el optimizador de Gradient Descent
    optimizador = tf.train.GradientDescentOptimizer(lr).minimize(costo)
    
    # Inicializamos las variables globales
    init = tf.global_variables_initializer()
    
    print('INICIANDO LA SESION')
    
    with tf.Session() as session:
        
        # Inicializamos las variables en la sesion
        session.run(init)
        
        # Iteramos el número de veces que indica el parámetro "epochs"
        for epoch in range(epochs):
            
            #
            for (_x, _y) in zip (x,y):
                session.run(optimizador, feed_dict = {X: _x, Y: _y})
                
            # Verificamos si debemos de imprimir el resultado
            if (epoch + 1) % imprimir_error_cada == 0:

                # Calculamos el costo de cada epoch
                c = session.run(costo, feed_dict = {X: x, Y: y})
                print('Iteración: ' + str(epoch + 1))
                print('Error del modelo: ' + str(c))
                
        # Obtenemos el costo y los estimados para Weights y Bias
        costos = session.run(costo, feed_dict = {X: x, Y: y})
        weights = session.run(m)
        bias = session.run(b)
        
        # retornamos el resultado de la estimación
        return costos, weights, bias

# %% [markdown]
# A continuación se crea una función que permite visualizar cómo cambia el error en cada iteración.

# %%
def grafica_error_iteracion(errores):
    iteraciones = errores[:,0]
    errores_valor = errores[:,1]
    plt.plot(iteraciones, errores_valor)
    plt.xlabel('# Iteración')
    plt.ylabel('Error')
    plt.title('Error por iteración')
    plt.grid()
    plt.show()

# %% [markdown]
# Crear una función que nos permita visualizar con matplotlib cómo evoluciona el modelo entrenado en el tiempo : Crear una función que tome como parámetro la estructura de datos conteniendo el historial de modelos ,y un valor “n” que indica cada cuantas iteraciones graficar el modelo resultante,  por ejemplo para n=3 la función debe graficar la recta correspondiente al modelo junto a los datos cada 3 iteraciones, si se ejecutaron 15 iteraciones , para n = 3 se grafica el modelo de las iteraciones 3,6,9,12,15 junto con los datos de entrenamiento.

# %%
def grafica_modelo(resultados, graficar_cada_iteraciones, x, y, x_label, y_label):
    for i in range(1, len(resultados)):
        if i % graficar_cada_iteraciones == 0:
            vector_mb = resultados[i]
            x_rango = np.array([np.nanmin(x), np.nanmax(x)])
            y_rango = vector_mb[0]* x_rango + vector_mb[1]
            signo = '+' if vector_mb[1] >= 0  else '-'
            
            plt.plot(x_rango, y_rango)
            plt.scatter(x, y, color="purple")
            plt.title("Modelo: " + str(vector_mb[0]) + "x " + signo + str(np.absolute(vector_mb[1])))
            plt.xlabel(x_label)
            plt.ylabel(y_label)
            plt.show()

# %% [markdown]
# # Uso de scikit-learn para generar modelos lineales
#
# A continuación utilizamos el paquete scikit-learn para generar y entrenar un modelo de regresión lineal que brinde una aproximación al valor de la variable dependiente a partir de la variable independiente.

# %%
def modelo_lineal_sklearn(x,y):
    #aplicamos el shape correcto a las variables de entrada
    x_ = x.reshape(x.size,-1)
    y_ = y.reshape(y.size,-1)
    
    regresion_lineal = linear_model.LinearRegression()
    regresion_lineal.fit(x_,y_)
    vector_mb = np.array([regresion_lineal.coef_[0], regresion_lineal.intercept_])
    return vector_mb.reshape(2)

# %% [markdown]
# # Función para obtener la estimación de la variable dependiente a partir de los modelos generados (iteración y scikit-learn)
#
# Ahora que se tienen dos modelos, uno generado mediante iteraciones y el otro generado a través de scikit-learn, definimos una función que nos retorna la predicción estimada de la variable dependiente a partir de promediar la predicción obtenida de cada modelo.

# %%
def evaluar_modelos(x, vector_mb_iteracion, vector_mb_sklearn):
    # Evaluamos para el modelo obtenido a partir de iteración
    # Se crea una matriz inicial con dos columnas. La primera es x y la segunda se inicaliza con 1
    matriz_entrenamiento_iteracion = np.column_stack((x, np.ones(x.shape[0], dtype=int)))
    yhat_iteracion = np.matmul(matriz_entrenamiento_iteracion, vector_mb_iteracion)
    
    # Evaluamos para el modelo obtenido a partir de scikit-learn
    # Se crea una matriz inicial con dos columnas. La primera es x y la segunda se inicaliza con 1
    matriz_entrenamiento_sklearn = np.column_stack((x, np.ones(x.shape[0], dtype=int)))
    yhat_sklearn = np.matmul(matriz_entrenamiento_sklearn, vector_mb_sklearn)
    
    # Calculamos el promedio de los y_hat_
    yhat_media = np.mean(np.array([yhat_sklearn, yhat_iteracion]), axis =0)
    
    return yhat_media, yhat_iteracion, yhat_sklearn

# %% [markdown]
# # Función para calcular el error de una estimación y_hat sobre el valor real de y (variable dependiente)
#
# Se crea una función para calcular el error de una estimación y_hat.

# %%
def calcular_error(y, yhat):
    error = (1/2)*np.mean(np.power(y - yhat, 2))
    return error;

# %% [markdown]
# # Evaluación de modelos para la variable independiente OverallQual
#
# Una vez tenemos las herramientas para construir y evaluar los modelos lineales a partir de los datos, procedemos a analizar la primer variable independiente: OverallQual.

# %% [markdown]
# Generación de posibles modelos a partir de iteraciones.

# %%
x_overall_quality = data_train[:,1].astype(np.float64)
y_overall_quality = data_train[:,0].astype(np.float64)
epochs_overall_quality = 60000
imprimir_error_cada_overall_quality = 5000
learning_rate_overall_quality = 0.012

#errores_overall_quality, diccionario_resultados_overall_quality = modelo_lineal(x_overall_quality, y_overall_quality, epochs_overall_quality, imprimir_error_cada_overall_quality, learning_rate_overall_quality)
errores, ms, bs = modelo_lineal_tf(x_overall_quality, y_overall_quality, epochs_overall_quality, imprimir_error_cada_overall_quality, learning_rate_overall_quality)

# %% [markdown]
# Graficamos los modelos obtenidos para las iteraciones que cumplan con el valor de la variable imprimir_error_cada.

# %%
grafica_modelo(diccionario_resultados_overall_quality, imprimir_error_cada_overall_quality, x_overall_quality, y_overall_quality, 'OverallQual', 'SalePrice')

# %% [markdown]
# Graficamos los errores para ver su comportamiento.

# %%
grafica_error_iteracion(errores_overall_quality)

# %% [markdown]
# Identificamos el modelo que produce el menor error.

# %%
indice_error_minimo_overall_quality = np.argmin(errores_overall_quality[:,1])
error_minimo_overall_quality = errores_overall_quality[indice_error_minimo_overall_quality]
iteracion_error_minimo_overall_quality = int(error_minimo_overall_quality[0])
print('Iteración en la que ocurrió el error mínimo: ')
print(iteracion_error_minimo_overall_quality)
print('Valor de m:')
print(diccionario_resultados_overall_quality[iteracion_error_minimo_overall_quality][0])
print('Valor de b:')
print(diccionario_resultados_overall_quality[iteracion_error_minimo_overall_quality][1])

vector_mb_iteracion_overall_quality = diccionario_resultados_overall_quality[iteracion_error_minimo_overall_quality]
# Out:
# Iteración en la que ocurrió el error mínimo:
# 31788
# Valor de m:
# 45411.99855411331
# Valor de b:
# -96469.56987748957

# %% [markdown]
# Obtenemos el modelo propuesto por scikit-learn.

# %%
vector_mb_scikit_overall_quality = modelo_lineal_sklearn(x_overall_quality,y_overall_quality)
print('Valor de m:')
print(vector_mb_scikit_overall_quality[0])
print('Valor de b:')
print(vector_mb_scikit_overall_quality[1])
# Out:
# Valor de m:
# 45411.998779159076
# Valor de b:
# -96469.57131873936

# %% [markdown]
# Evaluamos los modelos con el 20% de los datos cargados inicialmente que no se utilizaron. Se evalúan los resultados obtenidos.

# %%
# Obtenemos los valores de x y de los datos de prueba (20% del total)
x_overall_quality_test = data_test[:,1]
y_overall_quality_test = data_test[:,0]

yhat_media_overall_quality, yhat_iteracion_overall_quality, yhat_sklearn_overall_quality = evaluar_modelos(x_overall_quality_test, vector_mb_scikit_overall_quality, vector_mb_iteracion_overall_quality)

print('y estimada a partir de modelo de iteración')
print(yhat_iteracion_overall_quality)
print('\ny estimada a partir de modelo de scikit-learn')
print(yhat_sklearn_overall_quality)
print('\ny estimada a partir del promedio de los modelos')
print(yhat_media_overall_quality)
# Out:
# y estimada a partir de modelo de iteración
# [176002.42135622 357650.41647285 176002.42135622 176002.42135622
#  221414.42013537 130590.42257706 176002.42135622 266826.41891453
#  130590.42257706 176002.42135622 130590.42257706 130590.42257706
#  221414.42013537 266826.41891453 357650.41647285 130590.42257706
#  130590.42257706 130590.42257706  39766.42501874 266826.41891453
#  221414.42013537 221414.42013537  85178.4237979  266826.41891453
#  130590.42257706 176002.42135622 176002.42135622 176002.42135622
#  221414.42013537 221414.42013537 221414.42013537  85178.4237979
#   85178.4237979  221414.42013537 130590.42257706 221414.42013537
#  130590.42257706 221414.42013537  85178.4237979  176002.42135622
#  130590.42257706 266826.41891453 176002.42135622 266826.41891453
#   85178.4237979   85178.4237979  130590.42257706 130590.42257706
#  176002.42135622 266826.41891453  85178.4237979  176002.42135622
#  130590.42257706 130590.42257706 176002.42135622 130590.42257706
#  221414.42013537 176002.42135622 176002.42135622 130590.42257706
#  312238.41769369 130590.42257706 130590.42257706 130590.42257706
#   85178.4237979  130590.42257706 130590.42257706 130590.42257706
#  221414.42013537 221414.42013537 176002.42135622 266826.41891453
#  221414.42013537 221414.42013537 221414.42013537 357650.41647285
#  266826.41891453 176002.42135622 221414.42013537 176002.42135622
#  176002.42135622 130590.42257706 221414.42013537 221414.42013537
#  130590.42257706 221414.42013537 221414.42013537 176002.42135622
#  266826.41891453 130590.42257706 221414.42013537 176002.42135622
#  176002.42135622 130590.42257706  85178.4237979  176002.42135622
#  176002.42135622 221414.42013537 221414.42013537 312238.41769369
#  266826.41891453 130590.42257706 221414.42013537 176002.42135622
#  130590.42257706 176002.42135622 130590.42257706 130590.42257706
#  176002.42135622 176002.42135622 266826.41891453  85178.4237979
#  221414.42013537 221414.42013537 130590.42257706 176002.42135622
#  176002.42135622 176002.42135622 176002.42135622 130590.42257706
#  266826.41891453 266826.41891453 130590.42257706 130590.42257706
#  130590.42257706 221414.42013537 130590.42257706 130590.42257706
#  130590.42257706 176002.42135622 357650.41647285 130590.42257706
#  221414.42013537 176002.42135622 266826.41891453 221414.42013537
#  221414.42013537 312238.41769369 221414.42013537 130590.42257706
#  130590.42257706 176002.42135622 221414.42013537 221414.42013537
#  266826.41891453 312238.41769369  85178.4237979  176002.42135622
#  266826.41891453 221414.42013537 266826.41891453  85178.4237979
#  176002.42135622  39766.42501874 221414.42013537  85178.4237979
#  266826.41891453  85178.4237979   39766.42501874 130590.42257706
#  176002.42135622 221414.42013537 266826.41891453 130590.42257706
#   85178.4237979  130590.42257706 130590.42257706 176002.42135622
#  130590.42257706  85178.4237979  221414.42013537 130590.42257706
#   85178.4237979  176002.42135622 266826.41891453 176002.42135622
#  221414.42013537  85178.4237979  221414.42013537 266826.41891453
#  221414.42013537 266826.41891453 130590.42257706 176002.42135622
#  176002.42135622 266826.41891453 221414.42013537 221414.42013537
#  130590.42257706 130590.42257706 176002.42135622 312238.41769369
#  130590.42257706 221414.42013537  85178.4237979  176002.42135622
#  221414.42013537 221414.42013537 221414.42013537 130590.42257706
#  176002.42135622 266826.41891453  85178.4237979  176002.42135622
#  221414.42013537 357650.41647285 221414.42013537 266826.41891453
#  176002.42135622 130590.42257706 176002.42135622 130590.42257706
#   39766.42501874 176002.42135622 221414.42013537 130590.42257706
#  176002.42135622  85178.4237979  221414.42013537 176002.42135622
#  312238.41769369 176002.42135622 221414.42013537 130590.42257706
#  130590.42257706 176002.42135622 221414.42013537 266826.41891453
#  130590.42257706 130590.42257706 130590.42257706 176002.42135622
#  176002.42135622 176002.42135622 221414.42013537 266826.41891453
#   39766.42501874 266826.41891453 130590.42257706 130590.42257706
#   85178.4237979  221414.42013537 221414.42013537 176002.42135622
#   85178.4237979  266826.41891453 176002.42135622 221414.42013537
#   85178.4237979  266826.41891453 130590.42257706 176002.42135622
#  176002.42135622 176002.42135622 176002.42135622 176002.42135622
#  130590.42257706 176002.42135622 221414.42013537 130590.42257706
#  130590.42257706 176002.42135622 130590.42257706 176002.42135622
#   85178.4237979  176002.42135622 130590.42257706 176002.42135622
#   85178.4237979  266826.41891453 176002.42135622 221414.42013537
#  176002.42135622 176002.42135622 357650.41647285 176002.42135622
#  221414.42013537 176002.42135622 130590.42257706 266826.41891453
#   85178.4237979  130590.42257706 130590.42257706 266826.41891453
#  130590.42257706 130590.42257706 221414.42013537 176002.42135622
#  176002.42135622 221414.42013537 130590.42257706 130590.42257706]
#
# y estimada a partir de modelo de scikit-learn
# [176002.42144719 357650.41566364 176002.42144719 176002.42144719
#  221414.4200013  130590.42289308 176002.42144719 266826.41855542
#  130590.42289308 176002.42144719 130590.42289308 130590.42289308
#  221414.4200013  266826.41855542 357650.41566364 130590.42289308
#  130590.42289308 130590.42289308  39766.42578485 266826.41855542
#  221414.4200013  221414.4200013   85178.42433896 266826.41855542
#  130590.42289308 176002.42144719 176002.42144719 176002.42144719
#  221414.4200013  221414.4200013  221414.4200013   85178.42433896
#   85178.42433896 221414.4200013  130590.42289308 221414.4200013
#  130590.42289308 221414.4200013   85178.42433896 176002.42144719
#  130590.42289308 266826.41855542 176002.42144719 266826.41855542
#   85178.42433896  85178.42433896 130590.42289308 130590.42289308
#  176002.42144719 266826.41855542  85178.42433896 176002.42144719
#  130590.42289308 130590.42289308 176002.42144719 130590.42289308
#  221414.4200013  176002.42144719 176002.42144719 130590.42289308
#  312238.41710953 130590.42289308 130590.42289308 130590.42289308
#   85178.42433896 130590.42289308 130590.42289308 130590.42289308
#  221414.4200013  221414.4200013  176002.42144719 266826.41855542
#  221414.4200013  221414.4200013  221414.4200013  357650.41566364
#  266826.41855542 176002.42144719 221414.4200013  176002.42144719
#  176002.42144719 130590.42289308 221414.4200013  221414.4200013
#  130590.42289308 221414.4200013  221414.4200013  176002.42144719
#  266826.41855542 130590.42289308 221414.4200013  176002.42144719
#  176002.42144719 130590.42289308  85178.42433896 176002.42144719
#  176002.42144719 221414.4200013  221414.4200013  312238.41710953
#  266826.41855542 130590.42289308 221414.4200013  176002.42144719
#  130590.42289308 176002.42144719 130590.42289308 130590.42289308
#  176002.42144719 176002.42144719 266826.41855542  85178.42433896
#  221414.4200013  221414.4200013  130590.42289308 176002.42144719
#  176002.42144719 176002.42144719 176002.42144719 130590.42289308
#  266826.41855542 266826.41855542 130590.42289308 130590.42289308
#  130590.42289308 221414.4200013  130590.42289308 130590.42289308
#  130590.42289308 176002.42144719 357650.41566364 130590.42289308
#  221414.4200013  176002.42144719 266826.41855542 221414.4200013
#  221414.4200013  312238.41710953 221414.4200013  130590.42289308
#  130590.42289308 176002.42144719 221414.4200013  221414.4200013
#  266826.41855542 312238.41710953  85178.42433896 176002.42144719
#  266826.41855542 221414.4200013  266826.41855542  85178.42433896
#  176002.42144719  39766.42578485 221414.4200013   85178.42433896
#  266826.41855542  85178.42433896  39766.42578485 130590.42289308
#  176002.42144719 221414.4200013  266826.41855542 130590.42289308
#   85178.42433896 130590.42289308 130590.42289308 176002.42144719
#  130590.42289308  85178.42433896 221414.4200013  130590.42289308
#   85178.42433896 176002.42144719 266826.41855542 176002.42144719
#  221414.4200013   85178.42433896 221414.4200013  266826.41855542
#  221414.4200013  266826.41855542 130590.42289308 176002.42144719
#  176002.42144719 266826.41855542 221414.4200013  221414.4200013
#  130590.42289308 130590.42289308 176002.42144719 312238.41710953
#  130590.42289308 221414.4200013   85178.42433896 176002.42144719
#  221414.4200013  221414.4200013  221414.4200013  130590.42289308
#  176002.42144719 266826.41855542  85178.42433896 176002.42144719
#  221414.4200013  357650.41566364 221414.4200013  266826.41855542
#  176002.42144719 130590.42289308 176002.42144719 130590.42289308
#   39766.42578485 176002.42144719 221414.4200013  130590.42289308
#  176002.42144719  85178.42433896 221414.4200013  176002.42144719
#  312238.41710953 176002.42144719 221414.4200013  130590.42289308
#  130590.42289308 176002.42144719 221414.4200013  266826.41855542
#  130590.42289308 130590.42289308 130590.42289308 176002.42144719
#  176002.42144719 176002.42144719 221414.4200013  266826.41855542
#   39766.42578485 266826.41855542 130590.42289308 130590.42289308
#   85178.42433896 221414.4200013  221414.4200013  176002.42144719
#   85178.42433896 266826.41855542 176002.42144719 221414.4200013
#   85178.42433896 266826.41855542 130590.42289308 176002.42144719
#  176002.42144719 176002.42144719 176002.42144719 176002.42144719
#  130590.42289308 176002.42144719 221414.4200013  130590.42289308
#  130590.42289308 176002.42144719 130590.42289308 176002.42144719
#   85178.42433896 176002.42144719 130590.42289308 176002.42144719
#   85178.42433896 266826.41855542 176002.42144719 221414.4200013
#  176002.42144719 176002.42144719 357650.41566364 176002.42144719
#  221414.4200013  176002.42144719 130590.42289308 266826.41855542
#   85178.42433896 130590.42289308 130590.42289308 266826.41855542
#  130590.42289308 130590.42289308 221414.4200013  176002.42144719
#  176002.42144719 221414.4200013  130590.42289308 130590.42289308]
#
# y estimada a partir del promedio de los modelos
# [176002.4214017  357650.41606825 176002.4214017  176002.4214017
#  221414.42006834 130590.42273507 176002.4214017  266826.41873498
#  130590.42273507 176002.4214017  130590.42273507 130590.42273507
#  221414.42006834 266826.41873498 357650.41606825 130590.42273507
#  130590.42273507 130590.42273507  39766.42540179 266826.41873498
#  221414.42006834 221414.42006834  85178.42406843 266826.41873498
#  130590.42273507 176002.4214017  176002.4214017  176002.4214017
#  221414.42006834 221414.42006834 221414.42006834  85178.42406843
#   85178.42406843 221414.42006834 130590.42273507 221414.42006834
#  130590.42273507 221414.42006834  85178.42406843 176002.4214017
#  130590.42273507 266826.41873498 176002.4214017  266826.41873498
#   85178.42406843  85178.42406843 130590.42273507 130590.42273507
#  176002.4214017  266826.41873498  85178.42406843 176002.4214017
#  130590.42273507 130590.42273507 176002.4214017  130590.42273507
#  221414.42006834 176002.4214017  176002.4214017  130590.42273507
#  312238.41740161 130590.42273507 130590.42273507 130590.42273507
#   85178.42406843 130590.42273507 130590.42273507 130590.42273507
#  221414.42006834 221414.42006834 176002.4214017  266826.41873498
#  221414.42006834 221414.42006834 221414.42006834 357650.41606825
#  266826.41873498 176002.4214017  221414.42006834 176002.4214017
#  176002.4214017  130590.42273507 221414.42006834 221414.42006834
#  130590.42273507 221414.42006834 221414.42006834 176002.4214017
#  266826.41873498 130590.42273507 221414.42006834 176002.4214017
#  176002.4214017  130590.42273507  85178.42406843 176002.4214017
#  176002.4214017  221414.42006834 221414.42006834 312238.41740161
#  266826.41873498 130590.42273507 221414.42006834 176002.4214017
#  130590.42273507 176002.4214017  130590.42273507 130590.42273507
#  176002.4214017  176002.4214017  266826.41873498  85178.42406843
#  221414.42006834 221414.42006834 130590.42273507 176002.4214017
#  176002.4214017  176002.4214017  176002.4214017  130590.42273507
#  266826.41873498 266826.41873498 130590.42273507 130590.42273507
#  130590.42273507 221414.42006834 130590.42273507 130590.42273507
#  130590.42273507 176002.4214017  357650.41606825 130590.42273507
#  221414.42006834 176002.4214017  266826.41873498 221414.42006834
#  221414.42006834 312238.41740161 221414.42006834 130590.42273507
#  130590.42273507 176002.4214017  221414.42006834 221414.42006834
#  266826.41873498 312238.41740161  85178.42406843 176002.4214017
#  266826.41873498 221414.42006834 266826.41873498  85178.42406843
#  176002.4214017   39766.42540179 221414.42006834  85178.42406843
#  266826.41873498  85178.42406843  39766.42540179 130590.42273507
#  176002.4214017  221414.42006834 266826.41873498 130590.42273507
#   85178.42406843 130590.42273507 130590.42273507 176002.4214017
#  130590.42273507  85178.42406843 221414.42006834 130590.42273507
#   85178.42406843 176002.4214017  266826.41873498 176002.4214017
#  221414.42006834  85178.42406843 221414.42006834 266826.41873498
#  221414.42006834 266826.41873498 130590.42273507 176002.4214017
#  176002.4214017  266826.41873498 221414.42006834 221414.42006834
#  130590.42273507 130590.42273507 176002.4214017  312238.41740161
#  130590.42273507 221414.42006834  85178.42406843 176002.4214017
#  221414.42006834 221414.42006834 221414.42006834 130590.42273507
#  176002.4214017  266826.41873498  85178.42406843 176002.4214017
#  221414.42006834 357650.41606825 221414.42006834 266826.41873498
#  176002.4214017  130590.42273507 176002.4214017  130590.42273507
#   39766.42540179 176002.4214017  221414.42006834 130590.42273507
#  176002.4214017   85178.42406843 221414.42006834 176002.4214017
#  312238.41740161 176002.4214017  221414.42006834 130590.42273507
#  130590.42273507 176002.4214017  221414.42006834 266826.41873498
#  130590.42273507 130590.42273507 130590.42273507 176002.4214017
#  176002.4214017  176002.4214017  221414.42006834 266826.41873498
#   39766.42540179 266826.41873498 130590.42273507 130590.42273507
#   85178.42406843 221414.42006834 221414.42006834 176002.4214017
#   85178.42406843 266826.41873498 176002.4214017  221414.42006834
#   85178.42406843 266826.41873498 130590.42273507 176002.4214017
#  176002.4214017  176002.4214017  176002.4214017  176002.4214017
#  130590.42273507 176002.4214017  221414.42006834 130590.42273507
#  130590.42273507 176002.4214017  130590.42273507 176002.4214017
#   85178.42406843 176002.4214017  130590.42273507 176002.4214017
#   85178.42406843 266826.41873498 176002.4214017  221414.42006834
#  176002.4214017  176002.4214017  357650.41606825 176002.4214017
#  221414.42006834 176002.4214017  130590.42273507 266826.41873498
#   85178.42406843 130590.42273507 130590.42273507 266826.41873498
#  130590.42273507 130590.42273507 221414.42006834 176002.4214017
#  176002.4214017  221414.42006834 130590.42273507 130590.42273507]

# %% [markdown]
# Calculamos el error para cada modelo.

# %%
error_iteracion_overall_quality = calcular_error(y_overall_quality_test, yhat_iteracion_overall_quality)
error_sklearn_overall_quality = calcular_error(y_overall_quality_test, yhat_sklearn_overall_quality)
error_media_overall_quality = calcular_error(y_overall_quality_test, yhat_media_overall_quality)

print(error_iteracion_overall_quality)
print(error_sklearn_overall_quality)
print(error_media_overall_quality)
# Out:
# 1315091304.4743195
# 1315091304.3852875
# 1315091304.4298036

# %% [markdown]
# Graficamos los errores obtenidos.

# %%
etiquetas_overall_quality = ['Iteración', 'Scikit-learn', 'Promedio']
vector_errores_overall_quality = [error_iteracion_overall_quality, error_sklearn_overall_quality, error_media_overall_quality]


plt.bar([1,2,3], height= vector_errores_overall_quality) 
plt.xticks([1,2,3], etiquetas_overall_quality)
plt.title('Error por modelo para la variable independiente OverallQual')
plt.show()

# %% [markdown]
# # Conclusión de modelo para la variable independiente OverallQual
#
# A partir de la gráfica anterior podemos concluir que el modelo cuyo error es menor es el generado con scikit-learn.
#
# El modelo lineal que mejor se acopla a los datos es:

# %%
# Recordamos, la posición 0 de vector_mb_iteracion_overall_quality pertenece m y la posición 1 a b
signo_b_overall_quality = ' + ' if vector_mb_scikit_overall_quality[1] >= 0  else ' - '
print('Modelo lineal final con la forma: y = mx + b')
print('SalePrice = ' + str(vector_mb_scikit_overall_quality[0]) + "OverallQual " + signo_b_overall_quality + str(np.absolute(vector_mb_scikit_overall_quality[1])))
# Out:
# Modelo lineal final con la forma: y = mx + b
# SalePrice = 45411.998779159076OverallQual  - 96469.57131873936

# %% [markdown]
# # Evaluación de modelos para la variable independiente 1stFlrSF
#
# Una vez hemos seleccionado el modelo que mejor se acopla para la variable independiente OverallQual, procedemos a analizar la segunda variable seleccionada: 1stFlrSF.

# %% [markdown]
# Generación de posibles modelos a partir de iteraciones.

# %%
x_first_floor_sf = data_train[:,2]
y_first_floor_sf = data_train[:,0]
epochs_first_floor_sf = 800000
imprimir_error_cada_first_floor_sf = 100000
learning_rate_first_floor_sf = 0.000000001

errores_first_floor_sf, diccionario_resultados_first_floor_sf = modelo_lineal(x_first_floor_sf, y_first_floor_sf, epochs_first_floor_sf, imprimir_error_cada_first_floor_sf, learning_rate_first_floor_sf)
# Out:
# Iteración: 100000
# Error del modelo: 1968092264.870414
# Iteración: 200000
# Error del modelo: 1968091443.1482673
# Iteración: 300000
# Error del modelo: 1968090621.4416564
# Iteración: 400000
# Error del modelo: 1968089799.7505798
# Iteración: 500000
# Error del modelo: 1968088978.075039
# Iteración: 600000
# Error del modelo: 1968088156.4150324
# Iteración: 700000
# Error del modelo: 1968087334.77056
# Iteración: 800000
# Error del modelo: 1968086513.141622

# %% [markdown]
# Se ha intentado con 800000 iteraciones (epochs) y pareciera que la tendencia a reducir el error sigue a la baja, sin embargo se detendrá el proceso (podría seguirse intentando hasta encontrar el punto en el que el error empieza a incrementar de nuevo).
#
# Graficamos los modelos obtenidos para las iteraciones que cumplan con el valor de la variable imprimir_error_cada.

# %%
grafica_modelo(diccionario_resultados_first_floor_sf, imprimir_error_cada_first_floor_sf, x_first_floor_sf, y_first_floor_sf, '1stFlrSF', 'SalePrice')

# %% [markdown]
# Graficamos los errores para ver su comportamiento.

# %%
grafica_error_iteracion(errores_first_floor_sf)

# %% [markdown]
# Identificamos el modelo que produce el menor error.

# %%
indice_error_minimo_first_floor_sf = np.argmin(errores_first_floor_sf[:,1])
error_minimo_first_floor_sf = errores_first_floor_sf[indice_error_minimo_first_floor_sf]
iteracion_error_minimo_first_floor_sf = int(error_minimo_first_floor_sf[0])
print('Iteración en la que ocurrió el error mínimo: ')
print(iteracion_error_minimo_first_floor_sf)
print('Valor de m:')
print(diccionario_resultados_first_floor_sf[iteracion_error_minimo_first_floor_sf][0])
print('Valor de b:')
print(diccionario_resultados_first_floor_sf[iteracion_error_minimo_first_floor_sf][1])

vector_mb_iteracion_first_floor_sf = diccionario_resultados_first_floor_sf[iteracion_error_minimo_first_floor_sf]
# Out:
# Iteración en la que ocurrió el error mínimo:
# 800000
# Valor de m:
# 153.69526885644635
# Valor de b:
# 2.4135545636799645

# %% [markdown]
# Obtenemos el modelo propuesto por scikit-learn.

# %%
vector_mb_scikit_first_floor_sf = modelo_lineal_sklearn(x_first_floor_sf,y_first_floor_sf)
print('Valor de m:')
print(vector_mb_scikit_first_floor_sf[0])
print('Valor de b:')
print(vector_mb_scikit_first_floor_sf[1])
# Out:
# Valor de m:
# 129.95124228715713
# Valor de b:
# 30324.585174963693

# %% [markdown]
# Evaluamos los modelos con el 20% de los datos cargados inicialmente que no se utilizaron. Se evalúan los resultados obtenidos.

# %%
# Obtenemos los valores de x y de los datos de prueba (20% del total)
x_first_floor_sf_test = data_test[:,2]
y_first_floor_sf_test = data_test[:,0]

yhat_media_first_floor_sf, yhat_iteracion_first_floor_sf, yhat_sklearn_first_floor_sf = evaluar_modelos(x_first_floor_sf_test, vector_mb_scikit_first_floor_sf, vector_mb_iteracion_first_floor_sf)

print('y estimada a partir de modelo de iteración')
print(yhat_iteracion_first_floor_sf)
print('\ny estimada a partir de modelo de scikit-learn')
print(yhat_sklearn_first_floor_sf)
print('\ny estimada a partir del promedio de los modelos')
print(yhat_media_first_floor_sf)
# Out:
# y estimada a partir de modelo de iteración
# [190944.32064189 268265.30980275 175610.07405201 194193.10169907
#  111544.11160444 242924.81755675 182367.53865094 306990.78000432
#  150269.58180601 136624.70136586 136884.60385043 176389.78150573
#  199001.29766369 245004.03743335 343637.0303293  177169.48895945
#  234607.93805037 153648.31410548 162095.14485414 241365.40264931
#  138314.06751559 163914.46224616 241105.50016473 129607.33428235
#  139743.53118075 189384.90573444 116482.25881135 124929.08956001
#  144551.72714537 136234.847639   187825.490827   209917.20201581
#  142602.45851107 142862.36099564 145201.48335681 242145.11010303
#  169892.21939137 315697.51323756 167553.0970302  251241.69706313
#  197052.02902939 246043.64737164 167423.14578791 170671.92684509
#  117651.81999193 155077.77777063 160145.87621983 146500.99577968
#  201600.32250944 201080.51754029 117651.81999193 117651.81999193
#  148840.11814085 187695.53958471 182107.63616636 307900.43870033
#  132726.16409724 178209.09889775 146500.99577968 148840.11814085
#  251501.59954771 226161.10730171 207188.22592778 184966.56349668
#  189384.90573444 184706.66101211 163394.65727701 146241.09329511
#  129607.33428235 140393.28739219 178598.95262461 223172.2287291
#  145201.48335681 249812.23339797 182757.3923778  300103.3641631
#  133245.96906639 178469.00138232 128567.72434405 164694.16969988
#  177689.2939286  158716.41255467 304521.70640087 212906.08058842
#  143901.97093394 227330.66848229 129087.5293132  154947.82652835
#  288537.70359954 142602.45851107 181847.73368179 167293.19454563
#  146241.09329511 166773.38957648 173790.75665999 168072.90199935
#  204069.39611289 122979.82092571 155597.58273978 292566.19211045
#  286068.62999609 143901.97093394 203419.63990146 223821.98494054
#  151828.99671346 206668.42095864 116222.35632677 150919.33801745
#  125838.74825602 254360.52687802 176909.58647488 121030.5522914
#  234737.88929266 204329.29859747 165473.87715361 148840.11814085
#  251111.74582084 137534.36006187 202899.83493231 235907.45047325
#  245913.69612936 175869.97653658 180028.41628977 112193.86781587
#  209397.39704667 138444.01875788 142602.45851107 167033.29206105
#  176909.58647488 169632.3169068  640055.8139863  192243.83306476
#  160925.58367356 128177.87061719 186655.92964641 240325.79271101
#  157156.99764723 245004.03743335 208097.88462379 158976.31503925
#  176129.87902115 198481.49269455 277491.84800514 195882.4678488
#  219143.7402182  215115.2517073  153518.36286319 172231.34175254
#  242145.11010303 206018.6647472  262547.45514211 153518.36286319
#  222392.52127538 123889.47962172 168202.85324164 122330.06471427
#  263587.06508041 133765.77403554 130906.84670522 136364.79888128
#  236167.35295782 154428.0215592  236687.15792697 154298.07031691
#  136364.79888128 134675.43273155 129737.28552464 203679.54238603
#  245523.8424025  120380.79607996 149879.72807915 142602.45851107
#  143642.06844936 175090.26908286 197181.98027167 182627.44113551
#  124929.08956001 155077.77777063 310499.46354607 261117.99147695
#  224471.74115198 152218.85044032 204199.34735518 141822.75105734
#  132466.26161267 297114.4855905  159236.21752382 189125.00324987
#  146241.09329511 170412.02436052 130257.09049379 287628.04490353
#  158976.31503925 229149.98587431 196792.12654481 110374.55042385
#   97899.23116429 136104.89639671 144941.58087224 150529.48429058
#  140523.23863447 247083.25730994 139483.62869618 246173.59861393
#  174310.56162913 372486.20611705 163654.55976159 234477.98680809
#  132986.06658182 158196.60758553  93091.03519966 128307.82185948
#  142602.45851107 305431.36509688 160015.92497755 214335.54425358
#  121030.5522914  133765.77403554 211216.71443869 246563.45234079
#  257219.45420834 143252.2147225  228500.22966288 236167.35295782
#  147280.70323341 188995.05200758 225251.4486057  177559.34268631
#  249552.3309134  152348.8016826  177949.19641317 181068.02622807
#  153778.26534776 142602.45851107 198481.49269455 220573.20388336
#  120510.74732225 244224.32997962 130127.1392515  138573.97000017
#  126618.45570975 190944.32064189 152998.55789404 174830.36659828
#  165473.87715361 269954.67595248 167163.24330334 234218.08432351
#  192243.83306476 200560.71257114 178988.80635147 269954.67595248
#  122330.06471427 169242.46317993 140523.23863447 234997.79177724
#  204979.0548089  193023.54051848 189254.95449216 166513.4870919
#  134805.38397384 217454.37406847 125708.79701374 154817.87528606
#  156117.38770893 155337.68025521 176649.6839903  230059.64457032
#  142602.45851107 281390.38527375 190944.32064189 165473.87715361
#  215245.20294959 140523.23863447 163654.55976159 154038.16783234
#  215115.2517073  148970.06938314 184706.66101211 188865.1007653
#  133765.77403554 112193.86781587 146760.89826426 235387.6455041
#  169632.3169068  178469.00138232 188995.05200758 154168.11907462
#  299713.51043624 184706.66101211 170412.02436052 193543.34548763]
#
# y estimada a partir de modelo de scikit-learn
# [189969.76586113 281418.45083072 171833.72413607 193812.14758254
#   96061.95658984 251447.87340371 179825.87811661 327219.64094994
#  141863.14670906 125725.14347914 126032.53401685 172755.89574921
#  199498.87253023 253906.99770541 370561.70676746 173678.06736235
#  241611.3761969  145859.22369933 155849.416175   249603.53017743
#  127723.18197427 158001.14993899 249296.13963972 117425.59896089
#  129413.82993169 188125.42263485 101902.37680639 111892.56928206
#  135100.55487938 125264.05767257 186281.07940858 212409.27511417
#  132795.12584653 133102.51638425 135869.03122366 250525.70179057
#  165071.13230639 337517.22396332 162304.61746697 261284.37061052
#  197193.44349738 255136.55985626 162150.92219811 165993.30391953
#  103285.6342261  147549.87165675 153543.98714215 137405.98391223
#  202572.77790736 201957.99683193 103285.6342261  103285.6342261
#  140172.49875164 186127.38413972 179518.48757889 328295.50783193
#  121114.28541344 174907.6295132  137405.98391223 140172.49875164
#  261591.76114824 231621.18372123 209181.67446819 182899.78349373
#  188125.42263485 182592.39295602 157386.36886356 137098.59337451
#  117425.59896089 130182.30627597 175368.71531977 228086.19253753
#  135869.03122366 259593.7226531  180286.96392318 319073.79170055
#  121729.06648887 175215.02005091 116196.03681004 158923.32155213
#  174292.84843777 151853.33918473 324299.43084167 215944.26629787
#  134332.0785351  233004.44114094 116810.81788546 147396.1763879
#  305394.91277232 132795.12584653 179211.09704118 161997.22692926
#  137098.59337451 161382.44585383 169681.99037208 162919.3985424
#  205492.98801563 109587.14024921 148164.65273218 310159.46610687
#  302474.70266405 134332.0785351  204724.51167135 228854.66888181
#  143707.48993534 208566.89339276 101594.98626867 142631.62305335
#  112968.43616405 264973.05706308 173370.67682464 107281.71121636
#  241765.07146575 205800.37855335 159845.49316527 140172.49875164
#  261130.67534167 126801.01036113 204109.73059592 243148.32888546
#  254982.86458741 172141.11467378 177059.36327719  96830.43293412
#  211794.49403875 127876.87724313 132795.12584653 161689.83639155
#  173370.67682464 164763.74176867 721140.61502901 191506.7185497
#  154466.15875529 115734.95100347 184897.82198887 248373.96802658
#  150008.99595846 253906.99770541 210257.54135018 152160.72972245
#  172448.5052115  198884.09145481 292330.81491952 195810.18607768
#  223321.63920298 218557.08586843 145705.52843047 167837.6471458
#  250525.70179057 207798.41704848 274655.85900103 145705.52843047
#  227164.02092439 110663.00713121 163073.09381125 108818.66390493
#  275885.42115188 122343.84756429 118962.55164945 125417.75294142
#  243455.71942317 146781.39531247 244070.5004986  146627.70004361
#  125417.75294142 123419.71444629 117579.29422975 205031.90220906
#  254521.77878084 106513.23487208 141402.06090249 132795.12584653
#  134024.68799738 171218.94306064 197347.13876624 180133.26865432
#  111892.56928206 147549.87165675 331369.41320906 272965.21104361
#  229623.14522609 144168.57574191 205646.68328449 131872.95423339
#  120806.89487573 315538.80051685 152468.12026016 187818.03209714
#  137098.59337451 165685.91338181 118194.07530517 304319.04589033
#  152160.72972245 235156.17490493 196886.05295967  94678.69917013
#   79923.95335992 125110.36240371 135561.64068595 142170.53724678
#  130336.00154483 256366.12200712 129106.43939398 255290.25512512
#  170296.77144751 404682.05645359 157693.75940128 241457.68092804
#  121421.67595116 151238.55810931  74237.22841223 115888.64627232
#  132795.12584653 325375.29772366 153390.2918733  217634.91425529
#  107281.71121636 122343.84756429 213946.22780274 255751.34093169
#  268354.35297792 133563.60219082 234387.69856064 243455.71942317
#  138328.15552537 187664.33682828 230545.31683923 174139.15316892
#  259286.33211539 144322.27101077 174600.23897549 178288.92542804
#  146012.91896819 132795.12584653 198884.09145481 225012.2871604
#  106666.93014094 252984.82609227 118040.38003631 128030.57251198
#  113890.60777719 189969.76586113 145090.74735505 170911.55252293
#  159845.49316527 283416.48932585 161843.5316604  241150.29039033
#  191506.7185497  201343.21575651 175829.80112634 283416.48932585
#  108818.66390493 164302.6559621  130336.00154483 242072.46200347
#  206568.85489763 192428.89016283 187971.727366   161075.05531612
#  123573.40971515 221323.60070785 112814.7408952  147242.48111904
#  148779.4338076  147857.26219447 173063.28628692 236232.04178692
#  132795.12584653 296941.67298522 189969.76586113 159845.49316527
#  218710.78113729 130336.00154483 157693.75940128 146320.3095059
#  218557.08586843 140326.1940205  182592.39295602 187510.64155943
#  122343.84756429  96830.43293412 137713.37444994 242533.54781004
#  164763.74176867 175215.02005091 187664.33682828 146474.00477476
#  318612.70589398 182592.39295602 165685.91338181 193043.67123826]
#
# y estimada a partir del promedio de los modelos
# [190457.04325151 274841.88031673 173721.89909404 194002.62464081
#  103803.03409714 247186.34548023 181096.70838377 317105.21047713
#  146066.36425754 131174.9224225  131458.56893364 174572.83862747
#  199250.08509696 249455.51756938 357099.36854838 175423.7781609
#  238109.65712364 149753.7689024  158972.28051457 245484.46641337
#  133018.62474493 160957.80609258 245200.81990223 123516.46662162
#  134578.68055622 188755.16418465 109192.31780887 118410.82942104
#  139826.14101238 130749.45265578 187053.28511779 211163.23856499
#  137698.7921788  137982.43868994 140535.25729024 246335.4059468
#  167481.67584888 326607.36860044 164928.85724859 256263.03383683
#  197122.73626339 250590.10361395 164787.03399301 168332.61538231
#  110468.72710901 151313.82471369 156844.93168099 141953.48984595
#  202086.5502084  201519.25718611 110468.72710901 110468.72710901
#  144506.30844625 186911.46186222 180813.06187263 318097.97326613
#  126920.22475534 176558.36420547 141953.48984595 144506.30844625
#  256546.68034797 228891.14551147 208184.95019799 183933.17349521
#  188755.16418465 183649.52698406 160390.51307029 141669.84333481
#  123516.46662162 135287.79683408 176983.83397219 225629.21063332
#  140535.25729024 254702.97802554 181522.17815049 309588.57793182
#  127487.51777763 176842.01071662 122381.88057705 161808.74562601
#  175991.07118319 155284.8758697  314410.56862127 214425.17344315
#  139117.02473452 230167.55481162 122949.17359933 151172.00145812
#  296966.30818593 137698.7921788  180529.41536148 164645.21073744
#  141669.84333481 164077.91771516 171736.37351603 165496.15027087
#  204781.19206426 116283.48058746 151881.11773598 301362.82910866
#  294271.66633007 139117.02473452 204072.0757864  226338.32691118
#  147768.2433244  207617.6571757  108908.67129772 146775.4805354
#  119403.59221004 259666.79197055 175140.13164976 114156.13175388
#  238251.48037921 205064.83857541 162659.68515944 144506.30844625
#  256121.21058125 132167.6852115  203504.78276412 239527.88967935
#  250448.28035838 174005.54560518 178543.88978348 104512.150375
#  210595.94554271 133160.4480005  137698.7921788  164361.5642263
#  175140.13164976 167198.02933774 680598.21450766 191875.27580723
#  157695.87121442 121956.41081033 185776.87581764 244349.8803688
#  153582.99680284 249455.51756938 209177.71298699 155568.52238085
#  174289.19211633 198682.79207468 284911.33146233 195846.32696324
#  221232.68971059 216836.16878787 149611.94564683 170034.49444917
#  246335.4059468  206908.54089784 268601.65707157 149611.94564683
#  224778.27109989 117276.24337646 165637.97352645 115574.3643096
#  269736.24311615 128054.81079992 124934.69917734 130891.27591135
#  239811.5361905  150604.70843583 240378.82921278 150462.88518026
#  130891.27591135 129047.57358892 123658.28987719 204355.72229755
#  250022.81059167 113447.01547602 145640.89449082 137698.7921788
#  138833.37822337 173154.60607175 197264.55951896 181380.35489492
#  118410.82942104 151313.82471369 320934.43837757 267041.60126028
#  227047.44318904 148193.71309111 204923.01531983 136847.85264537
#  126636.5782442  306326.64305367 155852.16889199 188471.51767351
#  141669.84333481 168048.96887117 124225.58289948 295973.54539693
#  155568.52238085 232153.08038962 196839.08975224 102526.62479699
#   88911.5922621  130607.62940021 140251.61077909 146350.01076868
#  135429.62008965 251724.68965853 134295.03404508 250731.92686953
#  172303.66653832 388584.13128532 160674.15958143 237967.83386806
#  127203.87126649 154717.58284742  83664.13180594 122098.2340659
#  137698.7921788  315403.33141027 156703.10842542 215985.22925443
#  114156.13175388 128054.81079992 212581.47112071 251157.39663624
#  262786.90359313 138407.90845666 231443.96411176 239811.5361905
#  142804.42937939 188329.69441793 227898.38272247 175849.24792762
#  254419.33151439 148335.53634669 176274.71769433 179678.47582805
#  149895.59215798 137698.7921788  198682.79207468 222792.74552188
#  113588.83873159 248604.57803595 124083.75964391 133302.27125607
#  120254.53174347 190457.04325151 149044.65262454 172870.95956061
#  162659.68515944 276685.58263917 164503.38748187 237684.18735692
#  191875.27580723 200951.96416382 177409.3037389  276685.58263917
#  115574.3643096  166772.55957102 135429.62008965 238535.12689035
#  205773.95485327 192726.21534066 188613.34092908 163794.27120401
#  129189.39684449 219388.98738816 119261.76895447 151030.17820255
#  152448.41075827 151597.47122484 174856.48513861 233145.84317862
#  137698.7921788  289166.02912948 190457.04325151 162659.68515944
#  216977.99204344 135429.62008965 160674.15958143 150179.23866912
#  216836.16878787 144648.13170182 183649.52698406 188187.87116236
#  128054.81079992 104512.150375   142237.1363571  238960.59665707
#  167198.02933774 176842.01071662 188329.69441793 150321.06192469
#  309163.10816511 183649.52698406 168048.96887117 193293.50836295]

# %% [markdown]
# Calculamos el error para cada modelo.

# %%
error_iteracion_first_floor_sf = calcular_error(y_first_floor_sf_test, yhat_iteracion_first_floor_sf)
error_sklearn_first_floor_sf = calcular_error(y_first_floor_sf_test, yhat_sklearn_first_floor_sf)
error_media_first_floor_sf = calcular_error(y_first_floor_sf_test, yhat_media_first_floor_sf)

print(error_iteracion_first_floor_sf)
print(error_sklearn_first_floor_sf)
print(error_media_first_floor_sf)
# Out:
# 2292769137.345937
# 2437899262.471198
# 2351554532.9647913

# %% [markdown]
# Graficamos los errores obtenidos.

# %%
etiquetas_first_floor_sf = ['Iteración', 'Scikit-learn', 'Promedio']
vector_errores_first_floor_sf = [error_iteracion_first_floor_sf, error_sklearn_first_floor_sf, error_media_first_floor_sf]


plt.bar([1,2,3], height= vector_errores_first_floor_sf) 
plt.xticks([1,2,3], etiquetas_first_floor_sf)
plt.title('Error por modelo para la variable independiente 1stFlrSF')
plt.show()

# %% [markdown]
# # Conclusión de modelo para la variable independiente 1stFlrSF
#
# A partir de la gráfica anterior podemos concluir que el modelo cuyo error es menor es el generado a partir del entrenamiento iterativo que se hizo.
#
# El modelo lineal que mejor se acopla a los datos es:

# %%
# Recordamos, la posición 0 de vector_mb_iteracion_first_floor_sf pertenece m y la posición 1 a b
signo_b_first_floor_sf = ' + ' if vector_mb_iteracion_first_floor_sf[1] >= 0  else ' - '
print('Modelo lineal final con la forma: y = mx + b')
print('SalePrice = ' + str(vector_mb_iteracion_first_floor_sf[0]) + "1stFlrSF " + signo_b_first_floor_sf + str(np.absolute(vector_mb_iteracion_first_floor_sf[1])))
# Out:
# Modelo lineal final con la forma: y = mx + b
# SalePrice = 153.695268856446351stFlrSF  + 2.4135545636799645

# %% [markdown]
# # Comparación de errores entre modelos
#
# Comparamos los errores obtenidos mediante el modelo iterativo y mediante scikit-learn por medio de una gráfica.

# %%
# Parámetros generales de la gráfica
numero_modelos = 2
ancho_columna = 0.4

# Vectores con valor de los errores tanto para modelo iteración como para el de scikit-learn
vector_errores_iteracion = [error_iteracion_overall_quality, error_iteracion_first_floor_sf]
vector_errores_scikit = [error_sklearn_overall_quality, error_sklearn_first_floor_sf]

# Propiedades de la gráfica
fig, ax = plt.subplots()
indice = np.arange(numero_modelos)

columna_iteracion = ax.bar(indice, vector_errores_iteracion, ancho_columna, color='navy', label='Iteración')
columna_scikit = ax.bar(indice + ancho_columna, vector_errores_scikit, ancho_columna,color='teal', label='Scikit-learn')

ax.set_ylabel('Error')
ax.set_xticks(indice + ancho_columna / 2)
ax.set_xticklabels(['OverallQual', '1stFlrSF'])
ax.set_title('Error por modelo para las variables independientes')
ax.legend()
plt.show()
